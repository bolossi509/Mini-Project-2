# %% [markdown]
# # Ayiti Analytics Data Processing Bootcamp
# Ayiti Analytics Data wants to expand its training centers throughout all the communes of the country. Your role as a data analyst is to help them realize this dream.
#
# Its objective is to know which three communes of the country will be the most likely to expand its training centers.
#
# Knowing that each cohort must have 30 students
#
# * How many applications must be made to select 25% women for each on average
#
# * What are the most effective communication channels (Alumni, Facebook, WhatsApp, Friend ...) that will allow a student to be susceptible to selection
#
# * What is the average number of university students who should participate in this program
# * What will be the average number of applications per week that we could have
# * How many weeks should we extend the application process to select 60 students per commune?
# * If we were to do all the bootcamp online, who would be the best communes and how many applications would we need to select 30 student and what percentage of students would have a laptop, an internet connection, both at the same time
# * What are the most effective communication channels (Alumni, Facebook, WhatsApp, Friend ...) that will allow a women to be susceptible to selection
#
# ### NB
# Use the same framework of the BA project to complete this project

# %% [markdown]
# # We import the libraries we will need

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date

# %% [markdown]
# # Read CSV and Excel files

# %%
enroll = pd.read_csv("enroll.csv")
industry = pd.read_csv("industry.csv")
order = pd.read_csv("ord.csv")
quest =  pd.read_csv("quest.csv")
study_domain  = pd.read_csv("study_domain.csv")
technology =  pd.read_csv("technology.csv")
transaction =  pd.read_csv("transaction.csv")
Geo  = pd.read_excel('commune.xlsx', sheet_name= 0)

# %% [markdown]
# # Data Processing...

# %%
# Before the merging, we clean the created_at columns to make better process of the data 
#This code will turn all the values in the columns in string
quest['department'] = quest['department'].apply(lambda x  : str(x))
#This code will transform all the strings in uppercase. The goal is to match the value in the quest dataset with commune dataset 
quest['department']= quest['department'].apply(lambda x : x.upper())
quest['commune']= quest['commune'].apply(lambda x : x.upper())

# %%
#Here we can process with the merging
table1 = pd.merge(quest,Geo, how = 'left',left_on =['department','commune'],right_on = ['ADM1_PCODE','Commune_Id'])
table1.head()
# Out:
#    Unnamed: 0  gender         dob commune                   created_at  \
# 0           0    male  25/08/1998  HT0111  2021-02-14T23:03:52.768400Z
# 1           1  female  29/09/1996  HT0111  2021-02-16T16:01:10.861844Z
# 2           2    male  17/05/1996  HT0111  2021-02-16T16:56:30.579504Z
# 3           3    male  24/11/1996  HT0111  2021-02-16T16:57:55.754541Z
# 4           4    male  20/07/1997  HT0111  2021-02-16T17:05:40.907948Z
#
#                    modified_at department         education_level  \
# 0  2021-02-14T23:03:52.768462Z        NAN                 unknown
# 1  2021-02-16T16:01:10.861899Z       HT01     Bachelors (bacc +4)
# 2  2021-02-16T16:56:30.579563Z       HT01     Bachelors (bacc +4)
# 3  2021-02-16T16:57:55.754582Z       HT01     Bachelors (bacc +4)
# 4  2021-02-16T17:05:40.907982Z       HT01  High School (16 years)
#
#                                        university        study_domain  ...  \
# 0                                         unknown                  []  ...
# 1                                           other           ['other']  ...
# 2                 Université d'Etat d'Haïti (UEH)                  []  ...
# 3  Ecole Supérieure d'Infotronique d'Haïti (ESIH)  ['item1', 'item6']  ...
# 4                                         unknown           ['other']  ...
#
#   have_computer_home internet_at_home hear_AA_1  \
# 0            unknown          unknown   unknown
# 1                Yes              Yes    Friend
# 2                Yes              Yes    Friend
# 3                Yes              Yes      ESIH
# 4                Yes              Yes  WhatsApp
#
#                             after_AA                              quest_id  \
# 0                            unknown  905dc006-ce95-11eb-b2f9-7c67a234f601
# 1           Finding a job/internship  905ddcf2-ce95-11eb-9a92-7c67a234f601
# 2  Improving my data analysis skills  905e2608-ce95-11eb-809f-7c67a234f601
# 3  Improving my data analysis skills  905e4cf5-ce95-11eb-96a9-7c67a234f601
# 4                         Mentorship  905e73fd-ce95-11eb-a7b0-7c67a234f601
#
#        Commune_en      Commune_FR Commune_Id Departement ADM1_PCODE
# 0             NaN             NaN        NaN         NaN        NaN
# 1  Port-au-Prince  Port-au-Prince     HT0111        West       HT01
# 2  Port-au-Prince  Port-au-Prince     HT0111        West       HT01
# 3  Port-au-Prince  Port-au-Prince     HT0111        West       HT01
# 4  Port-au-Prince  Port-au-Prince     HT0111        West       HT01
#
# [5 rows x 22 columns]

# %%
#We will get rid of the timestamp in the values of the column created_at dataset
y = pd.DataFrame(table1.created_at.str.split('T',1).tolist(),columns = ['Date_created_at','To_drop'])
table1['created_at'] = y.iloc[:,0]
table1['created_at'].head()
# Out:
# 0    2021-02-14
# 1    2021-02-16
# 2    2021-02-16
# 3    2021-02-16
# 4    2021-02-16
# Name: created_at, dtype: object

# %%
#We start our data merging with the enroll and transaction dataset
table3=pd.merge(enroll,transaction, how = 'right',left_on =['user_id'],right_on = ['user_id'] )
# We do the same process with the enroll and ord dataset
table4 =pd.merge(enroll,order, how = 'right',left_on =['user_id'],right_on = ['user_id'] )
#We create a new column with categorical variable on each table to specify the name of the payment
table3['Payment Method'] = 'Moncash'
table4['Payment Method'] = 'Credit Card/Paypal'

# %%
# Here we did and slicing and data cleaning 
x = table4.loc[:,['Payment Method','quest_id_y']]
y = table3.loc[:,['Payment Method','quest_id']]
x=x.rename(columns = {'quest_id_y': 'quest_id'})
#Let's concatenate the dataframe  
z = pd.concat([x,y],axis = 0)
display(z.head(20))
# Out:
#         Payment Method                              quest_id
# 0   Credit Card/Paypal  906b3c86-ce95-11eb-b6a7-7c67a234f601
# 1   Credit Card/Paypal  906636cf-ce95-11eb-8679-7c67a234f601
# 2   Credit Card/Paypal  906968f5-ce95-11eb-9e1a-7c67a234f601
# 3   Credit Card/Paypal  9060477c-ce95-11eb-ace3-7c67a234f601
# 4   Credit Card/Paypal  9064ff29-ce95-11eb-a3d3-7c67a234f601
# 5   Credit Card/Paypal  9065740c-ce95-11eb-968f-7c67a234f601
# 6   Credit Card/Paypal  906a52b7-ce95-11eb-9c4b-7c67a234f601
# 7   Credit Card/Paypal  90617f12-ce95-11eb-a3c8-7c67a234f601
# 8   Credit Card/Paypal                                   NaN
# 9   Credit Card/Paypal  9061312a-ce95-11eb-ba28-7c67a234f601
# 10  Credit Card/Paypal  9064ff28-ce95-11eb-857f-7c67a234f601
# 11  Credit Card/Paypal  905ec1ec-ce95-11eb-8136-7c67a234f601
# 12  Credit Card/Paypal                                   NaN
# 13  Credit Card/Paypal  905f5dc1-ce95-11eb-bfa7-7c67a234f601
# 14  Credit Card/Paypal                                   NaN
# 15  Credit Card/Paypal  9062b754-ce95-11eb-b31e-7c67a234f601
# 16  Credit Card/Paypal  9069789f-ce95-11eb-9788-7c67a234f601
# 17  Credit Card/Paypal                                   NaN
# 0              Moncash  90659b00-ce95-11eb-9e8f-7c67a234f601
# 1              Moncash  9064c428-ce95-11eb-a021-7c67a234f601

# %%
final = pd.merge(table1,z,how = 'left', left_on = 'quest_id', right_on= 'quest_id')
final.reset_index(inplace = True ,level = 0)
final['Payment Method'] = final['Payment Method'].fillna('No Payment')
final =final.loc[:,['gender','dob','commune','created_at','department','education_level','university','current_employed','formal_sector_job','have_computer_home','internet_at_home','hear_AA_1','after_AA','quest_id','Commune_en','Commune_Id','Departement','Payment Method']]
final = final.set_index('quest_id')

# %%
print('Here we are displaying the head of our final dataframe \n')
display(final.head())
# Out:
# Here we are displaying the head of our final dataframe
#                                       gender         dob commune  created_at  \
# quest_id
# 905dc006-ce95-11eb-b2f9-7c67a234f601    male  25/08/1998  HT0111  2021-02-14
# 905ddcf2-ce95-11eb-9a92-7c67a234f601  female  29/09/1996  HT0111  2021-02-16
# 905e2608-ce95-11eb-809f-7c67a234f601    male  17/05/1996  HT0111  2021-02-16
# 905e4cf5-ce95-11eb-96a9-7c67a234f601    male  24/11/1996  HT0111  2021-02-16
# 905e73fd-ce95-11eb-a7b0-7c67a234f601    male  20/07/1997  HT0111  2021-02-16
#
#                                      department         education_level  \
# quest_id
# 905dc006-ce95-11eb-b2f9-7c67a234f601        NAN                 unknown
# 905ddcf2-ce95-11eb-9a92-7c67a234f601       HT01     Bachelors (bacc +4)
# 905e2608-ce95-11eb-809f-7c67a234f601       HT01     Bachelors (bacc +4)
# 905e4cf5-ce95-11eb-96a9-7c67a234f601       HT01     Bachelors (bacc +4)
# 905e73fd-ce95-11eb-a7b0-7c67a234f601       HT01  High School (16 years)
#
#                                                                           university  \
# quest_id
# 905dc006-ce95-11eb-b2f9-7c67a234f601                                         unknown
# 905ddcf2-ce95-11eb-9a92-7c67a234f601                                           other
# 905e2608-ce95-11eb-809f-7c67a234f601                 Université d'Etat d'Haïti (UEH)
# 905e4cf5-ce95-11eb-96a9-7c67a234f601  Ecole Supérieure d'Infotronique d'Haïti (ESIH)
# 905e73fd-ce95-11eb-a7b0-7c67a234f601                                         unknown
#
#                                      current_employed formal_sector_job  \
# quest_id
# 905dc006-ce95-11eb-b2f9-7c67a234f601          unknown           unknown
# 905ddcf2-ce95-11eb-9a92-7c67a234f601               No           unknown
# 905e2608-ce95-11eb-809f-7c67a234f601               No           unknown
# 905e4cf5-ce95-11eb-96a9-7c67a234f601               No           unknown
# 905e73fd-ce95-11eb-a7b0-7c67a234f601               No           unknown
#
#                                      have_computer_home internet_at_home  \
# quest_id
# 905dc006-ce95-11eb-b2f9-7c67a234f601            unknown          unknown
# 905ddcf2-ce95-11eb-9a92-7c67a234f601                Yes              Yes
# 905e2608-ce95-11eb-809f-7c67a234f601                Yes              Yes
# 905e4cf5-ce95-11eb-96a9-7c67a234f601                Yes              Yes
# 905e73fd-ce95-11eb-a7b0-7c67a234f601                Yes              Yes
#
#                                      hear_AA_1  \
# quest_id
# 905dc006-ce95-11eb-b2f9-7c67a234f601   unknown
# 905ddcf2-ce95-11eb-9a92-7c67a234f601    Friend
# 905e2608-ce95-11eb-809f-7c67a234f601    Friend
# 905e4cf5-ce95-11eb-96a9-7c67a234f601      ESIH
# 905e73fd-ce95-11eb-a7b0-7c67a234f601  WhatsApp
#
#                                                                after_AA  \
# quest_id
# 905dc006-ce95-11eb-b2f9-7c67a234f601                            unknown
# 905ddcf2-ce95-11eb-9a92-7c67a234f601           Finding a job/internship
# 905e2608-ce95-11eb-809f-7c67a234f601  Improving my data analysis skills
# 905e4cf5-ce95-11eb-96a9-7c67a234f601  Improving my data analysis skills
# 905e73fd-ce95-11eb-a7b0-7c67a234f601                         Mentorship
#
#                                           Commune_en Commune_Id Departement  \
# quest_id
# 905dc006-ce95-11eb-b2f9-7c67a234f601             NaN        NaN         NaN
# 905ddcf2-ce95-11eb-9a92-7c67a234f601  Port-au-Prince     HT0111        West
# 905e2608-ce95-11eb-809f-7c67a234f601  Port-au-Prince     HT0111        West
# 905e4cf5-ce95-11eb-96a9-7c67a234f601  Port-au-Prince     HT0111        West
# 905e73fd-ce95-11eb-a7b0-7c67a234f601  Port-au-Prince     HT0111        West
#
#                                      Payment Method
# quest_id
# 905dc006-ce95-11eb-b2f9-7c67a234f601     No Payment
# 905ddcf2-ce95-11eb-9a92-7c67a234f601     No Payment
# 905e2608-ce95-11eb-809f-7c67a234f601        Moncash
# 905e4cf5-ce95-11eb-96a9-7c67a234f601     No Payment
# 905e73fd-ce95-11eb-a7b0-7c67a234f601     No Payment

# %%
print('We are checking if our dataset has Na values  \n' )
display(final.isna().sum())
# Out:
# We are checking if our dataset has Na values
# gender                0
# dob                   6
# commune               0
# created_at            0
# department            0
# education_level       0
# university            0
# current_employed      0
# formal_sector_job     0
# have_computer_home    0
# internet_at_home      0
# hear_AA_1             0
# after_AA              0
# Commune_en            2
# Commune_Id            2
# Departement           2
# Payment Method        0
# dtype: int64

# %%
print('The column date of birth has 6 Na values   \n' )
display(final[final['dob'].isna()])
print('We will clean the missing values when wil be working on the dates columns')
# Out:
# The column date of birth has 6 Na values
#                                       gender  dob commune  created_at  \
# quest_id
# 9060e347-ce95-11eb-abbb-7c67a234f601    male  NaN  HT0111  2021-02-23
# 906241d5-ce95-11eb-9850-7c67a234f601    male  NaN  HT0111  2021-03-14
# 9065822a-ce95-11eb-9df5-7c67a234f601  female  NaN  HT0112  2021-03-03
# 9066fab1-ce95-11eb-a4e2-7c67a234f601  female  NaN  HT0113  2021-02-18
# 90691afb-ce95-11eb-a4c3-7c67a234f601    male  NaN  HT0131  2021-02-16
# 906a04c9-ce95-11eb-8f6a-7c67a234f601    male  NaN  HT0443  2021-02-19
#
#                                      department         education_level  \
# quest_id
# 9060e347-ce95-11eb-abbb-7c67a234f601       HT01                   Other
# 906241d5-ce95-11eb-9850-7c67a234f601       HT01     Bachelors (bacc +4)
# 9065822a-ce95-11eb-9df5-7c67a234f601       HT01     Bachelors (bacc +4)
# 9066fab1-ce95-11eb-a4e2-7c67a234f601       HT01     Bachelors (bacc +4)
# 90691afb-ce95-11eb-a4c3-7c67a234f601       HT01     Bachelors (bacc +4)
# 906a04c9-ce95-11eb-8f6a-7c67a234f601       HT04  High School (16 years)
#
#                                                                           university  \
# quest_id
# 9060e347-ce95-11eb-abbb-7c67a234f601                                         unknown
# 906241d5-ce95-11eb-9850-7c67a234f601  Ecole Supérieure d'Infotronique d'Haïti (ESIH)
# 9065822a-ce95-11eb-9df5-7c67a234f601                 Université d'Etat d'Haïti (UEH)
# 9066fab1-ce95-11eb-a4e2-7c67a234f601                 Université d'Etat d'Haïti (UEH)
# 90691afb-ce95-11eb-a4c3-7c67a234f601                                Université INUKA
# 906a04c9-ce95-11eb-8f6a-7c67a234f601                                         unknown
#
#                                      current_employed formal_sector_job  \
# quest_id
# 9060e347-ce95-11eb-abbb-7c67a234f601               No           unknown
# 906241d5-ce95-11eb-9850-7c67a234f601               No           unknown
# 9065822a-ce95-11eb-9df5-7c67a234f601               No           unknown
# 9066fab1-ce95-11eb-a4e2-7c67a234f601               No           unknown
# 90691afb-ce95-11eb-a4c3-7c67a234f601               No           unknown
# 906a04c9-ce95-11eb-8f6a-7c67a234f601          unknown           unknown
#
#                                      have_computer_home internet_at_home  \
# quest_id
# 9060e347-ce95-11eb-abbb-7c67a234f601                Yes              Yes
# 906241d5-ce95-11eb-9850-7c67a234f601                Yes              Yes
# 9065822a-ce95-11eb-9df5-7c67a234f601                Yes              Yes
# 9066fab1-ce95-11eb-a4e2-7c67a234f601                Yes              Yes
# 90691afb-ce95-11eb-a4c3-7c67a234f601                Yes              Yes
# 906a04c9-ce95-11eb-8f6a-7c67a234f601                Yes              Yes
#
#                                      hear_AA_1  \
# quest_id
# 9060e347-ce95-11eb-abbb-7c67a234f601  WhatsApp
# 906241d5-ce95-11eb-9850-7c67a234f601      ESIH
# 9065822a-ce95-11eb-9df5-7c67a234f601    Friend
# 9066fab1-ce95-11eb-a4e2-7c67a234f601  Facebook
# 90691afb-ce95-11eb-a4c3-7c67a234f601  WhatsApp
# 906a04c9-ce95-11eb-8f6a-7c67a234f601  LinkedIn
#
#                                                                after_AA  \
# quest_id
# 9060e347-ce95-11eb-abbb-7c67a234f601   Training to start my own company
# 906241d5-ce95-11eb-9850-7c67a234f601                              other
# 9065822a-ce95-11eb-9df5-7c67a234f601  Improving my data analysis skills
# 9066fab1-ce95-11eb-a4e2-7c67a234f601           Finding a job/internship
# 90691afb-ce95-11eb-a4c3-7c67a234f601   Training to start my own company
# 906a04c9-ce95-11eb-8f6a-7c67a234f601  Improving my data analysis skills
#
#                                               Commune_en Commune_Id  \
# quest_id
# 9060e347-ce95-11eb-abbb-7c67a234f601      Port-au-Prince     HT0111
# 906241d5-ce95-11eb-9850-7c67a234f601      Port-au-Prince     HT0111
# 9065822a-ce95-11eb-9df5-7c67a234f601              Delmas     HT0112
# 9066fab1-ce95-11eb-a4e2-7c67a234f601           Carrefour     HT0113
# 90691afb-ce95-11eb-a4c3-7c67a234f601  Croix-Des-Bouquets     HT0131
# 906a04c9-ce95-11eb-8f6a-7c67a234f601       Mombin Crochu     HT0443
#
#                                      Departement Payment Method
# quest_id
# 9060e347-ce95-11eb-abbb-7c67a234f601        West        Moncash
# 906241d5-ce95-11eb-9850-7c67a234f601        West        Moncash
# 9065822a-ce95-11eb-9df5-7c67a234f601        West     No Payment
# 9066fab1-ce95-11eb-a4e2-7c67a234f601        West     No Payment
# 90691afb-ce95-11eb-a4c3-7c67a234f601        West        Moncash
# 906a04c9-ce95-11eb-8f6a-7c67a234f601  North-East     No Payment
# We will clean the missing values when wil be working on the dates columns

# %%
#Working on the Date and Age of all applicants
# We will work on the date of birth columns.
final['dob'].replace({'3 aout 1977':'03/08/1977'},inplace = True)
final['dob'] = pd.to_datetime(final['dob'])
final['created_at'] = pd.to_datetime(final['created_at'])
final['dob']
# Out:
# quest_id
# 905dc006-ce95-11eb-b2f9-7c67a234f601   1998-08-25
# 905ddcf2-ce95-11eb-9a92-7c67a234f601   1996-09-29
# 905e2608-ce95-11eb-809f-7c67a234f601   1996-05-17
# 905e4cf5-ce95-11eb-96a9-7c67a234f601   1996-11-24
# 905e73fd-ce95-11eb-a7b0-7c67a234f601   1997-07-20
#                                           ...
# 906b3c84-ce95-11eb-8c2a-7c67a234f601   1994-02-15
# 906b3c85-ce95-11eb-9b87-7c67a234f601   1990-08-10
# 906b3c86-ce95-11eb-b6a7-7c67a234f601   1993-12-28
# 906b65e2-ce95-11eb-8b5c-7c67a234f601   1992-04-17
# 906b65e3-ce95-11eb-a294-7c67a234f601   1993-07-22
# Name: dob, Length: 250, dtype: datetime64[ns]

# %% [markdown]
# ##

# %%
#II - Setting up the Age columns and cleaning incorrect data.

#N.B : We replace incorrect data about age with the mean of the age  of the applicants



def Calculate_Age(born) :
    """
    This function will allow us to calcute the age of all the applicants by the end of the application process
    """
    today = date(2021,6,18)
    return today.year - born.year - ((today.month,today.day)< (born.month,born.day))

final['Age'] = final['dob'].apply(Calculate_Age)
final['Age'] = final['Age'].fillna(final['Age'].mean())
#we find incorrect input in dataset. we replace with mean of the age of the applicants
final['Age'].replace({(1,0,-1):final['Age'].mean()},inplace = True)
final['Age'] = final['Age'].apply(lambda x : int(x))
move = final.pop('Age')
final.insert(2,'Age',move)
final=final.rename(columns = {' Date_of_registration': 'Date'})
final.columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-e8e69e11fa7f> in <module>
#      15 final['Age'] = final['Age'].fillna(final['Age'].mean())
#      16 #we find incorrect input in dataset. we replace with mean of the age of the applicants
# ---> 17 final['Age'].replace({(1,0,-1):final['Age'].mean()},inplace = True)
#      18 final['Age'] = final['Age'].apply(lambda x : int(x))
#      19 move = final.pop('Age')
#
# ~\Anaconda\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4561         method="pad",
#    4562     ):
# -> 4563         return super().replace(
#    4564             to_replace=to_replace,
#    4565             value=value,
#
# ~\Anaconda\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6498                 to_replace, value = keys, values
#    6499
# -> 6500             return self.replace(
#    6501                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6502             )
#
# ~\Anaconda\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4561         method="pad",
#    4562     ):
# -> 4563         return super().replace(
#    4564             to_replace=to_replace,
#    4565             value=value,
#
# ~\Anaconda\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6541                         )
#    6542                     self._consolidate_inplace()
# -> 6543                     new_data = self._mgr.replace_list(
#    6544                         src_list=to_replace,
#    6545                         dest_list=value,
#
# ~\Anaconda\lib\site-packages\pandas\core\internals\managers.py in replace_list(self, src_list, dest_list, inplace, regex)
#     640         mask = ~isna(values)
#     641
# --> 642         masks = [comp(s, mask, regex) for s in src_list]
#     643
#     644         result_blocks = []
#
# ~\Anaconda\lib\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#     640         mask = ~isna(values)
#     641
# --> 642         masks = [comp(s, mask, regex) for s in src_list]
#     643
#     644         result_blocks = []
#
# ~\Anaconda\lib\site-packages\pandas\core\internals\managers.py in comp(s, mask, regex)
#     634
#     635             s = com.maybe_box_datetimelike(s)
# --> 636             return _compare_or_regex_search(values, s, regex, mask)
#     637
#     638         # Calculate the mask once, prior to the call of comp
#
# ~\Anaconda\lib\site-packages\pandas\core\internals\managers.py in _compare_or_regex_search(a, b, regex, mask)
#    2002         result = tmp
#    2003
# -> 2004     _check_comparison_types(result, a, b)
#    2005     return result
#    2006
#
# ~\Anaconda\lib\site-packages\pandas\core\internals\managers.py in _check_comparison_types(result, a, b)
#    1969                 type_names[0] = f"ndarray(dtype={a.dtype})"
#    1970
# -> 1971             raise TypeError(
#    1972                 f"Cannot compare types {repr(type_names[0])} and {repr(type_names[1])}"
#    1973             )
#
# TypeError: Cannot compare types 'ndarray(dtype=float64)' and 'tuple'

# %%
display(final['Age'].groupby(by= final['gender']).describe())
plt.figure(figsize=(10,6))
plt.title('Average age of applicants by Gender')
sns.boxplot(data=final,x="gender",y="Age")
# Out:
#         count       mean       std  min   25%   50%   75%   max
# gender
# female   47.0  25.393443  7.483055  0.0  22.0  25.0  27.5  45.0
# male    203.0  27.059033  7.009382 -1.0  24.0  26.0  30.0  50.0
# <AxesSubplot:title={'center':'Average age of applicants by Gender'}, xlabel='gender', ylabel='Age'>

# %%
display(final['Age'].groupby(by= final['education_level']).describe())
plt.figure(figsize=(12,6))
sns.boxplot(data=final,x="education_level",y="Age")
plt.title('Boxplot of applicants by education level')
# Out:
#                          count       mean        std   min   25%   50%    75%  \
# education_level
# Bachelors (bacc +4)      148.0  27.959459   4.916830  21.0  25.0  26.0  30.00
# Doctorate (PhD, MD, JD)    1.0  31.000000        NaN  31.0  31.0  31.0  31.00
# High School (16 years)    33.0  23.181818   3.477198  19.0  21.0  23.0  24.00
# Masters                   14.0  34.000000   7.452413  24.0  29.0  33.0  34.75
# Other                     51.0  26.725490   4.733195  21.0  23.0  26.0  29.00
# unknown                    3.0  31.000000  11.532563  22.0  24.5  27.0  35.50
#
#                           max
# education_level
# Bachelors (bacc +4)      46.0
# Doctorate (PhD, MD, JD)  31.0
# High School (16 years)   38.0
# Masters                  50.0
# Other                    40.0
# unknown                  44.0
# Text(0.5, 1.0, 'Boxplot of applicants by education level')

# %%
def generate_barchart(data=final, title ="",abs_value ="Total",rel_value="Percent",figsize =(15,8),ylabel="") :
    '''
    This function we define here will generate bar chart with more information on the data  
    '''
    plt.figure(figsize=figsize)
    axes = sns.barplot(data=data,x=data.index,y=abs_value)
    i=0
    for tot, perc in zip(data[abs_value],data[rel_value]):
        axes.text(i,
              tot/2,
              str(np.round(perc*100,2))+ "%",
               fontdict=dict(color='White',fontsize=12,horizontalalignment="center")
              )
        axes.text(i,
              tot+ 3,
              str(tot),
               fontdict=dict(color='blue',fontsize=12,horizontalalignment="center")
              )
          
    
        i+=1
    plt.title(title)
    plt.ylabel(ylabel)
    plt.show()

# %%
Com = final.Commune_en.value_counts().to_frame().iloc[:4,:]
Com.rename(columns={"Commune_en":"Total"},inplace=True)
Com1 = final.Commune_en.value_counts(normalize = True).to_frame().iloc[:4,:]
Com1.rename(columns={"Commune_en":"Percent"},inplace=True)
resul = pd.concat([Com,Com1],axis =1)

resul.reset_index()
display(resul)

generate_barchart(resul,title ="4 Communes with the more applicants", abs_value="Total",rel_value='Percent', ylabel='' )
# Out:
#                 Total   Percent
# Delmas             71  0.286290
# Port-au-Prince     57  0.229839
# Petion-Ville       29  0.116935
# Carrefour          23  0.092742

# %%
payment_table = pd.pivot_table(final,'Age',index='Commune_en',columns=['Payment Method'],aggfunc = ['count'],fill_value=0)
payment_table = payment_table.sort_values(by= ('count','Moncash'),ascending = False).iloc[:5,:2]
payment_table
# Out:
#                             count
# Payment Method Credit Card/Paypal Moncash
# Commune_en
# Delmas                          5      17
# Port-au-Prince                  5      13
# Petion-Ville                    0       5
# Tabarre                         0       4
# Carrefour                       0       4

# %% [markdown]
# ## How many applications must be made to select 25% women for each on average ?

# %%
gender_table = pd.pivot_table(final,'Age',index='Commune_en',columns=['gender'],aggfunc = ['count'],fill_value=0)
gender_table = gender_table.sort_values(by= ('count','female'),ascending = False)
gender_table['Total'] =gender_table[('count','female')] +gender_table[('count','male')]

gender_table['Percentage of female'] =gender_table[('count','female')]/(gender_table[('Total')])
t =gender_table.iloc[:4,:] 
t
# Out:
#                 count      Total Percentage of female
# gender         female male
# Commune_en
# Port-au-Prince     19   38    57             0.333333
# Delmas             12   59    71             0.169014
# Carrefour           6   17    23             0.260870
# Petion-Ville        4   25    29             0.137931

# %%
#gender_table.iloc[:4,:] 
t['mean']= np.round(t['Percentage of female'].mean(),4)
#Determinons le pourcentage d'applications manquants en moyenne par commune pour atteindre les 25%
t['perct_mean'] = 0.25 - t['mean']
t['expectation'] = np.round((t['perct_mean']) * t['Total'],0)
t['mean_excp'] = np.round((t['expectation'] + t[('count','female')]) / (t['Total'] + t['expectation']),4)
t['mean2'] = np.round(t['mean_excp'].mean(),2)
# Out:
# <ipython-input-27-0b63ccf314ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t['mean']= np.round(t['Percentage of female'].mean(),4)
# <ipython-input-27-0b63ccf314ee>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t['perct_mean'] = 0.25 - t['mean']
# <ipython-input-27-0b63ccf314ee>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t['expectation'] = np.round((t['perct_mean']) * t['Total'],0)
# <ipython-input-27-0b63ccf314ee>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t['mean_excp'] = np.round((t['expectation'] + t[('count','female')]) / (t['Total'] + t['expectation']),4)
# <ipython-input-27-0b63ccf314ee>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t['mean2'] = np.round(t['mean_excp'].mean(),2)

# %%
print('The number applications of women  to obtain 25 % on average should exceed :',np.round(t['expectation'].sum(),0), 'in the first 4 communes ')
display(t)
# Out:
# The number applications of women  to obtain 25 % on average should exceed : 5.0 in the first 4 communes
#                 count      Total Percentage of female    mean perct_mean  \
# gender         female male
# Commune_en
# Port-au-Prince     19   38    57             0.333333  0.2253     0.0247
# Delmas             12   59    71             0.169014  0.2253     0.0247
# Carrefour           6   17    23             0.260870  0.2253     0.0247
# Petion-Ville        4   25    29             0.137931  0.2253     0.0247
#
#                expectation mean_excp mean2
# gender
# Commune_en
# Port-au-Prince         1.0    0.3448  0.25
# Delmas                 2.0    0.1918  0.25
# Carrefour              1.0    0.2917  0.25
# Petion-Ville           1.0    0.1667  0.25

# %%
education_table = pd.pivot_table(final,'Age',index='Commune_en',columns=['education_level'],aggfunc = ['count'],fill_value=0)
display(education_table.sort_values(by=('count','Bachelors (bacc +4)'),ascending = False).iloc[:4,[0,1,3]])
# Out:
#                               count
# education_level Bachelors (bacc +4) Doctorate (PhD, MD, JD) Masters
# Commune_en
# Delmas                           41                       1       5
# Port-au-Prince                   28                       0       4
# Petion-Ville                     20                       0       1
# Carrefour                        17                       0       1

# %% [markdown]
# ## What is the average number of university students who should participate in this program

# %%
#We created a pivot table with commune as index and education level as columns 
educa_level = pd.pivot_table(final,'Age',index='Commune_en',columns='education_level',aggfunc = ['count'],fill_value=0)
educa_level = educa_level.sort_values(by=('count','Bachelors (bacc +4)'),ascending = False)
educa_level=educa_level.iloc[:4,[0,1,3]]
 
educa_level['sum'] = educa_level.sum(axis = 1)
educa_level['total']= resul['Total']
educa_level['mean'] = educa_level['sum']/educa_level['total']
display(educa_level)


print('The average number of university student who should participate in one cohort should be around',np.round(educa_level['mean'].mean(),1)*30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-2fd640c58d82> in <module>
#       5
#       6 educa_level['sum'] = educa_level.sum(axis = 1)
# ----> 7 educa_level['total']= result['Total']
#       8 educa_level['mean'] = educa_level['sum']/educa_level['total']
#       9 display(educa_level)
#
# NameError: name 'result' is not defined

# %% [markdown]
# To get this result, we calculate the average of the mean of all the university levels applicant in each commune.Then we use the proportion to find the number of applicants in one cohort

# %%
internet_access = pd.pivot_table(final,'Age',index='Commune_en',columns='internet_at_home',aggfunc = ['count'],fill_value=0)
internet_access = internet_access.sort_values(by=('count','Yes'),ascending = False)
internet_access = internet_access.iloc[:4,[1]]
internet_access['Percent']  = internet_access[('count','Yes')]/final.shape[0]
internet_access.rename(columns={"count":"Total"},inplace=True)
display(internet_access)
generate_barchart(internet_access,title = "4 communes where applicants have access to internet", abs_value = ('Total','Yes') , rel_value = 'Percent',ylabel='Number of applicants that have both access to internet')
# Out:
#                  Total Percent
# internet_at_home   Yes
# Commune_en
# Delmas              61   0.244
# Port-au-Prince      51   0.204
# Petion-Ville        25   0.100
# Carrefour           18   0.072

# %% [markdown]
# This graph here shows the 3 communes beside Port-au-Prince that have a higher access to internet.Delmas has the higher percentage of applicants that have access to internet followed by Petion-ville and Carrefour.

# %%
computer_access = pd.pivot_table(final,'Age',index='Commune_en',columns='have_computer_home',aggfunc = ['count'],fill_value=0)
computer_access = computer_access.sort_values(by=('count','Yes'),ascending = False)
computer_access = computer_access.iloc[:4,[1]]
computer_access
computer_access['Percent']  =computer_access[('count','Yes')]/final.shape[0]
computer_access.rename(columns={"count":"Total"},inplace=True)
display(computer_access)
generate_barchart(computer_access,title = "4 communes where applicants have access to computer at home", abs_value = ('Total','Yes') , rel_value = 'Percent',ylabel='Number of applicants that have both access to computer')
# Out:
#                    Total Percent
# have_computer_home   Yes
# Commune_en
# Delmas                66   0.264
# Port-au-Prince        56   0.224
# Petion-Ville          25   0.100
# Carrefour             21   0.084

# %% [markdown]
# This graph here shows the 3 communes beside Port-au-Prince that have a higher access to computer at Home.Delmas has the higher percentage of applicants that have computer at home followed by Petion-ville and Carrefour

# %% [markdown]
# This graph here shows the 3 communes beside Port-au-Prince that have a higher access to computer at Home and internet at home.Delmas has the higher percentage of applicants that have computer at home followed by Petion-ville and Carrefour

# %%
reg = pd.pivot_table(final,'Age',index='Commune_en',columns=['internet_at_home','have_computer_home'],aggfunc = ['count'],fill_value=0)
reg = reg.sort_values(by=('count','Yes','Yes'),ascending = False)
reg = reg.iloc[:4,[2,3]]
reg['Percent'] = reg[('count','Yes','Yes')]/final.shape[0]
reg.rename(columns={"count":"Total"},inplace=True)
print(reg)
generate_barchart(reg,title = "4 communes where applicants have access to internet and computer", abs_value = ('Total','Yes','Yes') , rel_value = 'Percent',ylabel='Number of applicants that have both access to internet and computer')
# Out:
#                    Total     Percent
# internet_at_home     Yes
# have_computer_home    No Yes
# Commune_en
# Delmas                 3  58   0.232
# Port-au-Prince         0  51   0.204
# Petion-Ville           4  21   0.084
# Carrefour              1  17   0.068

# %%
#Let's start by creating a pivot table on the communication channels and gender columns 
result2 = pd.pivot_table(final,'Age',index =['hear_AA_1'] ,columns=['gender'],aggfunc=['count'],fill_value = 0)
#we are sorting the values from biggest to smallest and filter the 3 first
result2= result2.sort_values(by = ('count','male'),ascending = False)
result2 = result2.iloc[:4,:]
result2
# Out:
#            count
# gender    female male
# hear_AA_1
# WhatsApp       9   57
# Friend        11   56
# Facebook       6   34
# LinkedIn       1   14

# %% [markdown]
# ## What are the most effective communication channels (Alumni, Facebook, WhatsApp, Friend ...) that will allow a student to be susceptible to selection ?

# %%
#first we did slicing by gender then by payment method
resul4 = final[final['gender'] == 'female']
resul4 = final[(final['Payment Method'] == 'Moncash') | (final['Payment Method'] == 'Credit Card/Paypal')]
#we did a pivot table on the column Hear AA and gender as gender 
result4 = pd.pivot_table(resul4,'Age',index = ['gender'],columns=['hear_AA_1'],aggfunc=['count'],fill_value = 0)
values = result4.T
display(values)
values["Total"] = values.sum(axis=1)
values = values.sort_values(by ="Total",ascending=True)
ax =values.sort_values(by ="Total",ascending=True)[["male","female"]].plot(kind="barh",figsize=(15,10),stacked= True,alpha =0.7)
ylab = ax.set_ylabel('Number of Paid Applicants')
xlab = ax.set_xlabel('Communications Channels')
title = ax.set_title('Which communications channels did the applicants that enroll for the course hear of AA ?')


index =0
c =0
for male, female ,total in zip(values['male'],values["female"],values["Total"]):
    if male != total and  female != total  :
        ax.text(male/2 ,
                index,
                str(np.round((male/total)*100,1)) + "%",
                fontdict=dict(color='white',fontsize=10,horizontalalignment="center",verticalalignment="center")
        )
        ax.text(male + female/2 ,
            index,
            str(np.round((female/total)*100,1)) + "%",
            fontdict=dict(color='blue',fontsize=10,horizontalalignment="center",verticalalignment="center")
        )
    elif female == total:
        ax.text(female/2 ,
            index,
            str(np.round((female/total)*100,1)) + "%",
            fontdict=dict(color='blue',fontsize=10,horizontalalignment="center",verticalalignment="center")
    )
    else:
        ax.text(male/2 ,
            index,
            str(np.round((male/total)*100,1)) + "%",
            fontdict=dict(color='white',fontsize=10,horizontalalignment="center",verticalalignment="center")
    )
    ax.text(total+0.3 ,
            index,
            str(total),
            fontdict=dict(color='blue',fontsize=10,horizontalalignment="center",verticalalignment="center")
    )
    index+=1
# Out:
# gender                         female  male
#       hear_AA_1
# count Ayiti Analytics Website       0     3
#       Bootcamp Alumni               3     5
#       ESIH                          0     4
#       Facebook                      2     7
#       Friend                        3    19
#       Instagram                     0     1
#       LinkedIn                      1     2
#       WhatsApp                      4     9
#       other                         1     1

# %% [markdown]
# ## What are the most effective communication channels (Alumni, Facebook, WhatsApp, Friend ...) that will allow a women to be susceptible to selection ?

# %%
resul4 = final[(final['Payment Method'] == 'Moncash') | (final['Payment Method'] == 'Credit Card/Paypal')]

result5 = pd.pivot_table(resul4,'Age',index = ['gender'],columns=['hear_AA_1'],aggfunc=['count'],fill_value = 0)
values = result5.T
values = values.iloc[:,[0]]
display(values)
values["Total"] = values.sum(axis=1)
values = values.sort_values(by ="Total",ascending=True)
ax =values.sort_values(by ="Total",ascending=True)[["female"]].plot(kind="barh",figsize=(15,10),stacked= True,alpha =0.7)
ylab = ax.set_ylabel('Number of Applicants')
xlab = ax.set_xlabel('Communications Channels')
title = ax.set_title('Which communications channels did the women that enroll  hear of AA ?')
display(values)
index =0
c =0
for  female ,total in zip(values["female"],values["Total"]):
    if   female != total  :
        ax.text(female/2 ,
                index,
                str(np.round((female)*100,1)) + "%",
                fontdict=dict(color='white',fontsize=10,horizontalalignment="center",verticalalignment="center")
        )
    
    elif  total==0:
        ax.text(female/2 + 1.0,
            index,
            0,
            fontdict=dict(color='blue',fontsize=10,horizontalalignment="center",verticalalignment="center")
    )
    else:
        ax.text(total+0.3 ,
            index,
            str(total),
            fontdict=dict(color='blue',fontsize=10,horizontalalignment="center",verticalalignment="center")
    )
    index+=1
# Out:
# gender                         female
#       hear_AA_1
# count Ayiti Analytics Website       0
#       Bootcamp Alumni               3
#       ESIH                          0
#       Facebook                      2
#       Friend                        3
#       Instagram                     0
#       LinkedIn                      1
#       WhatsApp                      4
#       other                         1
# gender                         female  Total
#       hear_AA_1
# count Ayiti Analytics Website       0      0
#       ESIH                          0      0
#       Instagram                     0      0
#       LinkedIn                      1      1
#       other                         1      1
#       Facebook                      2      2
#       Bootcamp Alumni               3      3
#       Friend                        3      3
#       WhatsApp                      4      4

# %% [markdown]
# ## - What will be the average number of applications per week that we could have ?

# %%
final['date'] = ""
dg = final.groupby(pd.Grouper(key='created_at', freq='7D'))['date'].value_counts().to_frame()
dg['Number of weeks'] = ['Week 1','Week 2','Week 3','Week 4','Week 5']
dg = dg.set_index('Number of weeks')

# %%
#Setting up the mean column in the table 
dg['mean'] = dg.date.mean()
print('The average number of applications per week should be ',dg['mean'][0])
display(dg)

#plotting  the table
plt.grid=True
plt.plot(dg.index,dg.date,label='Registration')
plt.plot(dg.index,dg['mean'],label='mean',linestyle = '--')
plt.title('Applications per week')
plt.show()
# Out:
# The average number of applications per week should be  50.0
#                  date  mean
# Number of weeks
# Week 1            136  50.0
# Week 2             54  50.0
# Week 3             29  50.0
# Week 4             29  50.0
# Week 5              2  50.0

# %% [markdown]
# ### Conclusion
#
# After getting all of the insights through the dataset, The communes we have identified where Ayiti analytics could extend their training centers should be Delmas, Carrefour and Petion-ville. These communes have the higher access to internet and computer after the diagnostic analysis, but we will need to test our hypothesis.
#
#
# They are also the top of communes with the more courses paid, applicants from these regions shows a lot of interest and if Ayiti analytics were to made an only online boot camp, these communes should be on top but there as many factors as internet penetrations by communes, electricity access that could undermine this project we will need more data to draw more insights about this question.
#
# Ayiti analytics want to see more women engage in data science, we saw that the effective communications channels are Whatsapp, friends. Participating in a bootcamp can be challenging, Friends can be a great source of motivation as we saw mostly those who paid for the next steps hear from AA via a Friend or Social media.But still our analysis is based on descriptive analysis, and we will need to provide a more in-depth analysis
